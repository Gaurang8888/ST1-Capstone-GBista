# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import plotly.graph_objects as go
import plotly.express as px
# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATA.csv')

# %%
df.head()
# Out:
#   student_id  age  sex  graduated_h_school_type  scholarship_type  \
# 0   STUDENT1    2    2                        3                 3
# 1   STUDENT2    2    2                        3                 3
# 2   STUDENT3    2    2                        2                 3
# 3   STUDENT4    1    1                        1                 3
# 4   STUDENT5    2    2                        1                 3
#
#    additional_work  activity  partner  total_salary  transport  ...  \
# 0                1         2        2             1          1  ...
# 1                1         2        2             1          1  ...
# 2                2         2        2             2          4  ...
# 3                1         2        1             2          1  ...
# 4                2         2        1             3          1  ...
#
#    preparation_midterm_company  preparation_midterm_time  taking_notes  \
# 0                            1                         1             3
# 1                            1                         1             3
# 2                            1                         1             2
# 3                            1                         2             3
# 4                            2                         1             2
#
#    listenning  discussion_improves_interest  flip_classrom  grade_previous  \
# 0           2                             1              2               1
# 1           2                             3              2               2
# 2           2                             1              1               2
# 3           2                             2              1               3
# 4           2                             2              1               2
#
#    grade_expected  course_id  grade
# 0               1          1      1
# 1               3          1      1
# 2               2          1      1
# 3               2          1      1
# 4               2          1      1
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#      student_id  age  sex  graduated_h_school_type  scholarship_type  \
# 140  STUDENT141    2    1                        2                 3
# 141  STUDENT142    1    1                        2                 4
# 142  STUDENT143    1    1                        1                 4
# 143  STUDENT144    2    1                        2                 4
# 144  STUDENT145    1    1                        1                 5
#
#      additional_work  activity  partner  total_salary  transport  ...  \
# 140                1         1        2             1          1  ...
# 141                2         2        2             1          4  ...
# 142                2         2        2             1          1  ...
# 143                1         1        1             5          2  ...
# 144                2         2        2             3          1  ...
#
#      preparation_midterm_company  preparation_midterm_time  taking_notes  \
# 140                            1                         1             2
# 141                            1                         1             3
# 142                            1                         1             3
# 143                            2                         1             2
# 144                            2                         1             3
#
#      listenning  discussion_improves_interest  flip_classrom  grade_previous  \
# 140           1                             2              1               3
# 141           2                             2              1               5
# 142           3                             2              1               4
# 143           1                             2              1               5
# 144           2                             3              1               5
#
#      grade_expected  course_id  grade
# 140               3          9      5
# 141               3          9      5
# 142               3          9      1
# 143               3          9      4
# 144               4          9      3
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (145, 33)

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'sex', 'graduated_h_school_type',
#        'scholarship_type', 'additional_work', 'activity', 'partner',
#        'total_salary', 'transport', 'accomodation', 'mother_ed', 'farther_ed',
#        'siblings', 'parental_status', 'mother_occup', 'father_occup',
#        'weekly_study_hours', 'reading_non_scientific', 'reading_scientific',
#        'attendance_seminars_dep', 'impact_of_projects', 'attendances_classes',
#        'preparation_midterm_company', 'preparation_midterm_time',
#        'taking_notes', 'listenning', 'discussion_improves_interest',
#        'flip_classrom', 'grade_previous', 'grade_expected', 'course_id',
#        'grade'],
#       dtype='object')

# %%
df.nunique()
# Out:
# student_id                      145
# age                               3
# sex                               2
# graduated_h_school_type           3
# scholarship_type                  5
# additional_work                   2
# activity                          2
# partner                           2
# total_salary                      5
# transport                         4
# accomodation                      4
# mother_ed                         6
# farther_ed                        6
# siblings                          5
# parental_status                   3
# mother_occup                      5
# father_occup                      5
# weekly_study_hours                5
# reading_non_scientific            3
# reading_scientific                3
# attendance_seminars_dep           2
# impact_of_projects                3
# attendances_classes               2
# preparation_midterm_company       3
# preparation_midterm_time          3
# taking_notes                      3
# listenning                        3
# discussion_improves_interest      3
# flip_classrom                     3
# grade_previous                    5
# grade_expected                    4
# course_id                         9
# grade                             8
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   student_id                    145 non-null    object
#  1   age                           145 non-null    int64
#  2   sex                           145 non-null    int64
#  3   graduated_h_school_type       145 non-null    int64
#  4   scholarship_type              145 non-null    int64
#  5   additional_work               145 non-null    int64
#  6   activity                      145 non-null    int64
#  7   partner                       145 non-null    int64
#  8   total_salary                  145 non-null    int64
#  9   transport                     145 non-null    int64
#  10  accomodation                  145 non-null    int64
#  11  mother_ed                     145 non-null    int64
#  12  farther_ed                    145 non-null    int64
#  13  siblings                      145 non-null    int64
#  14  parental_status               145 non-null    int64
#  15  mother_occup                  145 non-null    int64
#  16  father_occup                  145 non-null    int64
#  17  weekly_study_hours            145 non-null    int64
#  18  reading_non_scientific        145 non-null    int64
#  19  reading_scientific            145 non-null    int64
#  20  attendance_seminars_dep       145 non-null    int64
#  21  impact_of_projects            145 non-null    int64
#  22  attendances_classes           145 non-null    int64
#  23  preparation_midterm_company   145 non-null    int64
#  24  preparation_midterm_time      145 non-null    int64
#  25  taking_notes                  145 non-null    int64
#  26  listenning                    145 non-null    int64
#  27  discussion_improves_interest  145 non-null    int64
#  28  flip_classrom                 145 non-null    int64
#  29  grade_previous                145 non-null    int64
#  30  grade_expected                145 non-null    int64
#  31  course_id                     145 non-null    int64
#  32  grade                         145 non-null    int64
# dtypes: int64(32), object(1)
# memory usage: 37.5+ KB

# %%
sns.set(style="ticks")
plt.rcParams['figure.figsize'] = (50, 30)
sns.heatmap(df.corr(), annot = True, linewidths=.8, cmap="Reds")
plt.title('Corelation Chart', fontsize = 30)
plt.show()
# Out:
# <ipython-input-11-6e7538db120e>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, linewidths=.8, cmap="Reds")

# %%
fig = plt.figure(figsize =(18,18))
ax=fig.gca()
df.hist(ax=ax,bins =30)
plt.show()
# Out:
# <ipython-input-33-b58145cf451f>:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax=ax,bins =30)

# %% [markdown]
# The Code below is for PDA STAGE 1

# %%
import numpy
from numpy import arange
from matplotlib import pyplot
from pandas import read_csv
from pandas import set_option
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
#from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error
# %matplotlib inline
#import warnings
#warnings.filterwarnings('ignore')
import pandas as pd
import sklearn 
import numpy as np
#from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
#from sklearn.linear_model import LogisticRegression
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATA.csv')
test = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATA.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATA.csv')

# %%
features = ['age', 'sex', 'graduated_h_school_type',
       'scholarship_type', 'additional_work', 'activity', 'partner',
       'total_salary', 'transport', 'accomodation', 'mother_ed', 'farther_ed',
       'weekly_study_hours', 'reading_non_scientific', 'reading_scientific',
       'attendance_seminars_dep', 'impact_of_projects', 'attendances_classes',
       'preparation_midterm_company', 'preparation_midterm_time',
       'taking_notes', 'listenning', 'discussion_improves_interest',
       'flip_classrom', 'grade_previous', 'course_id']
x_train = train[list(features)].values
y_train = train["grade"].values
x_test = test[list(features)].values
y = list('grade')
num_folds = 10
seed = 7
scoring = "accuracy"

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x_train, y_train, test_size = 0.20, random_state=seed)

np.shape(x_train), np.shape(x_test)
# Out:
# ((116, 26), (29, 26))

# %%
models = []
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
models.append(('GBM', GradientBoostingClassifier()))
models.append(('RF', RandomForestClassifier()))
results = []
names = []
print("Accuracy Rates on Training set")
for name, model in models:
  kfold = KFold(n_splits=num_folds,shuffle=True,random_state=seed)
  cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring= 'accuracy')
  results.append(cv_results)
  names.append(name)
  msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
  msg += '\n'
  print(msg)
# Out:
# Accuracy Rates on Training set
# NB: 0.156818 (0.085713)
#
# SVM: 0.217424 (0.108365)
#
# GBM: 0.268939 (0.141009)
#
# RF: 0.321970 (0.175498)

# %%
rf = RandomForestClassifier(n_estimators = 10)
rf.fit(x_train, y_train)
sur = rf.predict(x_test)

# %%
print(sur)
# Out:
# [0 2 5 1 7 5 2 7 6 7 1 0 1 7 1 7 2 1 5 4 2 2 5 6 2 1 1 1 2]

# %%
len(sur)
# Out:
# 29

# %%
for x in range(len(sur)):
  print("Predicted: ", sur[x], "Actual: ", y_train[x], "Data: ", x_test[x])
# Out:
# Predicted:  0 Actual:  3 Data:  [1 1 1 4 1 1 2 4 2 3 5 5 3 3 3 1 3 1 3 2 3 1 3 3 4 1]
# Predicted:  2 Actual:  3 Data:  [1 1 2 4 1 1 1 1 1 3 2 3 4 2 2 2 1 1 2 2 3 3 2 1 3 9]
# Predicted:  5 Actual:  3 Data:  [2 2 2 3 1 1 1 2 2 3 3 3 2 2 2 1 1 1 1 1 3 2 3 3 5 1]
# Predicted:  1 Actual:  3 Data:  [2 1 2 3 2 2 2 2 1 1 2 2 2 2 2 1 1 2 1 1 2 2 2 1 2 1]
# Predicted:  7 Actual:  1 Data:  [1 2 2 4 2 1 2 1 4 2 2 4 2 3 2 1 1 1 1 1 3 1 2 1 4 7]
# Predicted:  5 Actual:  6 Data:  [1 1 2 4 1 1 2 1 1 3 1 3 2 2 2 1 1 1 2 1 2 3 2 1 4 7]
# Predicted:  2 Actual:  2 Data:  [1 1 1 5 2 1 2 1 1 2 1 2 2 2 3 2 1 1 2 1 3 2 3 1 5 9]
# Predicted:  7 Actual:  2 Data:  [1 2 2 5 2 1 1 1 4 2 1 2 1 2 2 1 1 1 3 1 3 3 2 2 3 8]
# Predicted:  6 Actual:  6 Data:  [1 2 2 4 2 1 1 1 1 1 4 3 2 2 2 1 1 1 1 1 2 2 3 1 5 3]
# Predicted:  7 Actual:  4 Data:  [2 2 1 2 2 1 2 2 1 1 5 4 2 3 2 1 1 1 3 2 2 1 2 3 2 4]
# Predicted:  1 Actual:  7 Data:  [1 1 1 5 2 2 2 3 1 1 3 1 3 1 1 1 1 1 2 1 3 2 3 1 5 9]
# Predicted:  0 Actual:  1 Data:  [2 1 2 3 1 1 2 1 4 2 3 3 2 3 2 1 3 1 1 1 3 3 2 1 3 9]
# Predicted:  1 Actual:  2 Data:  [3 2 2 3 1 2 2 2 1 2 1 4 3 2 2 1 1 2 1 1 3 2 2 3 4 1]
# Predicted:  7 Actual:  1 Data:  [1 2 2 4 2 1 2 1 1 2 2 2 3 2 2 1 1 1 3 2 2 2 2 1 4 7]
# Predicted:  1 Actual:  1 Data:  [1 1 2 3 2 2 2 1 2 2 4 4 2 2 2 1 1 1 1 1 2 3 2 2 1 7]
# Predicted:  7 Actual:  3 Data:  [1 2 1 3 2 1 1 1 2 2 4 4 3 2 2 1 1 1 2 2 3 2 3 1 4 7]
# Predicted:  2 Actual:  5 Data:  [1 1 2 4 2 1 2 1 2 3 1 1 2 2 2 2 1 1 1 1 2 1 2 1 2 9]
# Predicted:  1 Actual:  3 Data:  [1 2 1 4 2 2 2 2 4 1 2 3 2 2 2 1 1 1 2 1 2 2 2 1 3 1]
# Predicted:  5 Actual:  5 Data:  [2 1 3 3 1 1 2 1 1 1 1 2 1 2 2 1 1 2 1 1 2 3 3 1 3 1]
# Predicted:  4 Actual:  1 Data:  [2 2 2 4 1 2 1 2 1 1 3 1 2 2 3 1 1 1 1 1 3 3 2 3 4 5]
# Predicted:  2 Actual:  1 Data:  [2 2 3 4 1 2 1 3 1 1 1 1 1 1 3 1 1 2 2 1 2 1 2 1 4 1]
# Predicted:  2 Actual:  1 Data:  [1 2 2 3 2 2 1 3 1 1 2 4 1 1 2 1 3 2 2 1 2 1 2 1 2 1]
# Predicted:  5 Actual:  6 Data:  [2 2 2 3 2 2 1 1 1 1 3 2 2 2 2 1 1 1 1 1 3 2 2 3 5 2]
# Predicted:  6 Actual:  6 Data:  [1 2 3 5 1 1 1 1 2 3 3 4 2 2 3 1 1 1 1 1 3 2 2 1 4 7]
# Predicted:  2 Actual:  4 Data:  [2 1 2 5 1 2 1 1 1 1 1 1 3 3 2 2 3 1 2 2 3 2 3 2 2 8]
# Predicted:  1 Actual:  3 Data:  [1 1 2 3 1 1 1 1 2 3 3 3 2 2 2 2 1 1 3 1 3 2 2 1 2 9]
# Predicted:  1 Actual:  1 Data:  [1 2 1 3 2 2 2 2 1 1 2 3 1 2 2 1 1 1 1 1 3 1 2 1 2 1]
# Predicted:  1 Actual:  5 Data:  [1 2 2 3 2 2 1 4 1 1 2 3 3 2 2 1 1 1 1 1 2 2 2 1 4 1]
# Predicted:  2 Actual:  4 Data:  [1 2 1 2 2 2 1 2 2 2 6 5 2 2 2 2 1 2 3 1 2 2 2 2 1 4]

# %% [markdown]
# BELOW IS THE CODE FOR STAGE 2 of PDA

# %%
train = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATAPREP2.csv')
test = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATAPREP2.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATAPREP2.csv')

# %%
features = ['age', 'sex', 'graduated_h_school_type',
       'scholarship_type', 'additional_work', 'activity', 'partner',
       'total_salary', 'transport', 'accomodation', 'mother_ed', 'farther_ed',
       'weekly_study_hours', 'reading_non_scientific', 'reading_scientific',
       'attendance_seminars_dep', 'impact_of_projects', 'attendances_classes',
       'preparation_midterm_company', 'preparation_midterm_time',
       'taking_notes', 'listenning', 'discussion_improves_interest',
       'flip_classrom', 'grade_previous', 'course_id']

x_train = train[list(features)].values
y_train = train["grade"].values
x_test = test[list(features)].values
y = list('grade')
num_folds = 10
seed = 7
scoring = "accuracy"

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x_train, y_train, test_size = 0.20, random_state=seed)

np.shape(x_train), np.shape(x_test)
# Out:
# ((116, 26), (29, 26))

# %%
models = []
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
models.append(('GBM', GradientBoostingClassifier()))
models.append(('RF', RandomForestClassifier()))
results = []
names = []
print("Accuracy Rates on Training set")
for name, model in models:
  kfold = KFold(n_splits=num_folds,shuffle=True,random_state=seed)
  cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring= 'accuracy')
  results.append(cv_results)
  names.append(name)
  msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
  msg += '\n'
  print(msg)
# Out:
# Accuracy Rates on Training set
# NB: 0.493182 (0.115661)
#
# SVM: 0.779545 (0.121753)
#
# GBM: 0.671970 (0.073999)
#
# RF: 0.684848 (0.141251)

# %%
rf = RandomForestClassifier(n_estimators = 10)
rf.fit(x_train, y_train)
sur = rf.predict(x_test)

# %%
np.shape(x_train), np.shape(x_test)
# Out:
# ((116, 26), (29, 26))

# %%
print(sur)
# Out:
# ['Satisfactory' 'Satisfactory' 'Satisfactory' 'Satisfactory'
#  'Above Average' 'Above Average' 'Above Average' 'Above Average'
#  'Above Average' 'Above Average' 'Satisfactory' 'Above Average'
#  'Satisfactory' 'Above Average' 'Above Average' 'Above Average'
#  'Satisfactory' 'Satisfactory' 'Satisfactory' 'Above Average'
#  'Satisfactory' 'Satisfactory' 'Satisfactory' 'Above Average'
#  'Satisfactory' 'fail' 'Satisfactory' 'Satisfactory' 'Above Average']

# %%
len(sur)
# Out:
# 29

# %%
for x in range(len(sur)):
  print("Predicted: ", sur[x], "Actual: ", y_train[x], "Data: ", x_test[x])
# Out:
# Predicted:  Satisfactory Actual:  Satisfactory Data:  [1 1 1 4 1 1 2 4 2 3 5 5 3 3 3 1 3 1 3 2 3 1 3 3 4 1]
# Predicted:  Satisfactory Actual:  Satisfactory Data:  [1 1 2 4 1 1 1 1 1 3 2 3 4 2 2 2 1 1 2 2 3 3 2 1 3 9]
# Predicted:  Satisfactory Actual:  Satisfactory Data:  [2 2 2 3 1 1 1 2 2 3 3 3 2 2 2 1 1 1 1 1 3 2 3 3 5 1]
# Predicted:  Satisfactory Actual:  Satisfactory Data:  [2 1 2 3 2 2 2 2 1 1 2 2 2 2 2 1 1 2 1 1 2 2 2 1 2 1]
# Predicted:  Above Average Actual:  Satisfactory Data:  [1 2 2 4 2 1 2 1 4 2 2 4 2 3 2 1 1 1 1 1 3 1 2 1 4 7]
# Predicted:  Above Average Actual:  Above Average Data:  [1 1 2 4 1 1 2 1 1 3 1 3 2 2 2 1 1 1 2 1 2 3 2 1 4 7]
# Predicted:  Above Average Actual:  Satisfactory Data:  [1 1 1 5 2 1 2 1 1 2 1 2 2 2 3 2 1 1 2 1 3 2 3 1 5 9]
# Predicted:  Above Average Actual:  Satisfactory Data:  [1 2 2 5 2 1 1 1 4 2 1 2 1 2 2 1 1 1 3 1 3 3 2 2 3 8]
# Predicted:  Above Average Actual:  Above Average Data:  [1 2 2 4 2 1 1 1 1 1 4 3 2 2 2 1 1 1 1 1 2 2 3 1 5 3]
# Predicted:  Above Average Actual:  Above Average Data:  [2 2 1 2 2 1 2 2 1 1 5 4 2 3 2 1 1 1 3 2 2 1 2 3 2 4]
# Predicted:  Satisfactory Actual:  Above Average Data:  [1 1 1 5 2 2 2 3 1 1 3 1 3 1 1 1 1 1 2 1 3 2 3 1 5 9]
# Predicted:  Above Average Actual:  Satisfactory Data:  [2 1 2 3 1 1 2 1 4 2 3 3 2 3 2 1 3 1 1 1 3 3 2 1 3 9]
# Predicted:  Satisfactory Actual:  Satisfactory Data:  [3 2 2 3 1 2 2 2 1 2 1 4 3 2 2 1 1 2 1 1 3 2 2 3 4 1]
# Predicted:  Above Average Actual:  Satisfactory Data:  [1 2 2 4 2 1 2 1 1 2 2 2 3 2 2 1 1 1 3 2 2 2 2 1 4 7]
# Predicted:  Above Average Actual:  Satisfactory Data:  [1 1 2 3 2 2 2 1 2 2 4 4 2 2 2 1 1 1 1 1 2 3 2 2 1 7]
# Predicted:  Above Average Actual:  Satisfactory Data:  [1 2 1 3 2 1 1 1 2 2 4 4 3 2 2 1 1 1 2 2 3 2 3 1 4 7]
# Predicted:  Satisfactory Actual:  Above Average Data:  [1 1 2 4 2 1 2 1 2 3 1 1 2 2 2 2 1 1 1 1 2 1 2 1 2 9]
# Predicted:  Satisfactory Actual:  Satisfactory Data:  [1 2 1 4 2 2 2 2 4 1 2 3 2 2 2 1 1 1 2 1 2 2 2 1 3 1]
# Predicted:  Satisfactory Actual:  Above Average Data:  [2 1 3 3 1 1 2 1 1 1 1 2 1 2 2 1 1 2 1 1 2 3 3 1 3 1]
# Predicted:  Above Average Actual:  Satisfactory Data:  [2 2 2 4 1 2 1 2 1 1 3 1 2 2 3 1 1 1 1 1 3 3 2 3 4 5]
# Predicted:  Satisfactory Actual:  Satisfactory Data:  [2 2 3 4 1 2 1 3 1 1 1 1 1 1 3 1 1 2 2 1 2 1 2 1 4 1]
# Predicted:  Satisfactory Actual:  Satisfactory Data:  [1 2 2 3 2 2 1 3 1 1 2 4 1 1 2 1 3 2 2 1 2 1 2 1 2 1]
# Predicted:  Satisfactory Actual:  Above Average Data:  [2 2 2 3 2 2 1 1 1 1 3 2 2 2 2 1 1 1 1 1 3 2 2 3 5 2]
# Predicted:  Above Average Actual:  Above Average Data:  [1 2 3 5 1 1 1 1 2 3 3 4 2 2 3 1 1 1 1 1 3 2 2 1 4 7]
# Predicted:  Satisfactory Actual:  Above Average Data:  [2 1 2 5 1 2 1 1 1 1 1 1 3 3 2 2 3 1 2 2 3 2 3 2 2 8]
# Predicted:  fail Actual:  Satisfactory Data:  [1 1 2 3 1 1 1 1 2 3 3 3 2 2 2 2 1 1 3 1 3 2 2 1 2 9]
# Predicted:  Satisfactory Actual:  Satisfactory Data:  [1 2 1 3 2 2 2 2 1 1 2 3 1 2 2 1 1 1 1 1 3 1 2 1 2 1]
# Predicted:  Satisfactory Actual:  Above Average Data:  [1 2 2 3 2 2 1 4 1 1 2 3 3 2 2 1 1 1 1 1 2 2 2 1 4 1]
# Predicted:  Above Average Actual:  Above Average Data:  [1 2 1 2 2 2 1 2 2 2 6 5 2 2 2 2 1 2 3 1 2 2 2 2 1 4]

# %% [markdown]
# BELOW IS THE CODE FOR STAGE 3 of PDA

# %%
train = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATAPREP.csv')
test = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATAPREP.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Capstone/CapstoneDATAPREP.csv')

# %%
features = ['age', 'sex', 'graduated_h_school_type',
       'scholarship_type', 'additional_work', 'activity', 'partner',
       'total_salary', 'transport', 'accomodation', 'mother_ed', 'farther_ed',
       'weekly_study_hours', 'reading_non_scientific', 'reading_scientific',
       'attendance_seminars_dep', 'impact_of_projects', 'attendances_classes',
       'preparation_midterm_company', 'preparation_midterm_time',
       'taking_notes', 'listenning', 'discussion_improves_interest',
       'flip_classrom', 'grade_previous', 'course_id']
x_train = train[list(features)].values
y_train = train["grade"].values
x_test = test[list(features)].values
y = list('grade')
num_folds = 10
seed = 7
scoring = "accuracy"

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x_train, y_train, test_size = 0.20, random_state=seed)

np.shape(x_train), np.shape(x_test)
# Out:
# ((116, 26), (29, 26))

# %%
models = []
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
models.append(('GBM', GradientBoostingClassifier()))
models.append(('RF', RandomForestClassifier()))
# evaluate each model in turn
results = []
names = []
print("Accuracy Rates on Training set")
for name, model in models:
  kfold = KFold(n_splits=num_folds,shuffle=True,random_state=seed)
  cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring= 'accuracy')
  results.append(cv_results)
  names.append(name)
  msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
  msg += '\n'
  print(msg)
# Out:
# Accuracy Rates on Training set
# NB: 0.747727 (0.112980)
#
# SVM: 0.949242 (0.055778)
#
# GBM: 0.906818 (0.069106)
#
# RF: 0.949242 (0.055778)

# %%
rf = RandomForestClassifier(n_estimators = 10)
rf.fit(x_train, y_train)
sur = rf.predict(x_test)

# %%
np.shape(x_train), np.shape(x_test)
# Out:
# ((116, 26), (29, 26))

# %%
print(sur)
# Out:
# ['Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass'
#  'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass'
#  'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass' 'Pass']

# %%
len(sur)
# Out:
# 29

# %%
for x in range(len(sur)):
  print("Predicted: ", sur[x], "Actual: ", y_train[x], "Data: ", x_test[x])
# Out:
# Predicted:  Pass Actual:  Pass Data:  [1 1 1 4 1 1 2 4 2 3 5 5 3 3 3 1 3 1 3 2 3 1 3 3 4 1]
# Predicted:  Pass Actual:  Pass Data:  [1 1 2 4 1 1 1 1 1 3 2 3 4 2 2 2 1 1 2 2 3 3 2 1 3 9]
# Predicted:  Pass Actual:  Pass Data:  [2 2 2 3 1 1 1 2 2 3 3 3 2 2 2 1 1 1 1 1 3 2 3 3 5 1]
# Predicted:  Pass Actual:  Pass Data:  [2 1 2 3 2 2 2 2 1 1 2 2 2 2 2 1 1 2 1 1 2 2 2 1 2 1]
# Predicted:  Pass Actual:  Pass Data:  [1 2 2 4 2 1 2 1 4 2 2 4 2 3 2 1 1 1 1 1 3 1 2 1 4 7]
# Predicted:  Pass Actual:  Pass Data:  [1 1 2 4 1 1 2 1 1 3 1 3 2 2 2 1 1 1 2 1 2 3 2 1 4 7]
# Predicted:  Pass Actual:  Pass Data:  [1 1 1 5 2 1 2 1 1 2 1 2 2 2 3 2 1 1 2 1 3 2 3 1 5 9]
# Predicted:  Pass Actual:  Pass Data:  [1 2 2 5 2 1 1 1 4 2 1 2 1 2 2 1 1 1 3 1 3 3 2 2 3 8]
# Predicted:  Pass Actual:  Pass Data:  [1 2 2 4 2 1 1 1 1 1 4 3 2 2 2 1 1 1 1 1 2 2 3 1 5 3]
# Predicted:  Pass Actual:  Pass Data:  [2 2 1 2 2 1 2 2 1 1 5 4 2 3 2 1 1 1 3 2 2 1 2 3 2 4]
# Predicted:  Pass Actual:  Pass Data:  [1 1 1 5 2 2 2 3 1 1 3 1 3 1 1 1 1 1 2 1 3 2 3 1 5 9]
# Predicted:  Pass Actual:  Pass Data:  [2 1 2 3 1 1 2 1 4 2 3 3 2 3 2 1 3 1 1 1 3 3 2 1 3 9]
# Predicted:  Pass Actual:  Pass Data:  [3 2 2 3 1 2 2 2 1 2 1 4 3 2 2 1 1 2 1 1 3 2 2 3 4 1]
# Predicted:  Pass Actual:  Pass Data:  [1 2 2 4 2 1 2 1 1 2 2 2 3 2 2 1 1 1 3 2 2 2 2 1 4 7]
# Predicted:  Pass Actual:  Pass Data:  [1 1 2 3 2 2 2 1 2 2 4 4 2 2 2 1 1 1 1 1 2 3 2 2 1 7]
# Predicted:  Pass Actual:  Pass Data:  [1 2 1 3 2 1 1 1 2 2 4 4 3 2 2 1 1 1 2 2 3 2 3 1 4 7]
# Predicted:  Pass Actual:  Pass Data:  [1 1 2 4 2 1 2 1 2 3 1 1 2 2 2 2 1 1 1 1 2 1 2 1 2 9]
# Predicted:  Pass Actual:  Pass Data:  [1 2 1 4 2 2 2 2 4 1 2 3 2 2 2 1 1 1 2 1 2 2 2 1 3 1]
# Predicted:  Pass Actual:  Pass Data:  [2 1 3 3 1 1 2 1 1 1 1 2 1 2 2 1 1 2 1 1 2 3 3 1 3 1]
# Predicted:  Pass Actual:  Pass Data:  [2 2 2 4 1 2 1 2 1 1 3 1 2 2 3 1 1 1 1 1 3 3 2 3 4 5]
# Predicted:  Pass Actual:  Pass Data:  [2 2 3 4 1 2 1 3 1 1 1 1 1 1 3 1 1 2 2 1 2 1 2 1 4 1]
# Predicted:  Pass Actual:  Pass Data:  [1 2 2 3 2 2 1 3 1 1 2 4 1 1 2 1 3 2 2 1 2 1 2 1 2 1]
# Predicted:  Pass Actual:  Pass Data:  [2 2 2 3 2 2 1 1 1 1 3 2 2 2 2 1 1 1 1 1 3 2 2 3 5 2]
# Predicted:  Pass Actual:  Pass Data:  [1 2 3 5 1 1 1 1 2 3 3 4 2 2 3 1 1 1 1 1 3 2 2 1 4 7]
# Predicted:  Pass Actual:  Pass Data:  [2 1 2 5 1 2 1 1 1 1 1 1 3 3 2 2 3 1 2 2 3 2 3 2 2 8]
# Predicted:  Pass Actual:  Pass Data:  [1 1 2 3 1 1 1 1 2 3 3 3 2 2 2 2 1 1 3 1 3 2 2 1 2 9]
# Predicted:  Pass Actual:  Pass Data:  [1 2 1 3 2 2 2 2 1 1 2 3 1 2 2 1 1 1 1 1 3 1 2 1 2 1]
# Predicted:  Pass Actual:  Pass Data:  [1 2 2 3 2 2 1 4 1 1 2 3 3 2 2 1 1 1 1 1 2 2 2 1 4 1]
# Predicted:  Pass Actual:  Pass Data:  [1 2 1 2 2 2 1 2 2 2 6 5 2 2 2 2 1 2 3 1 2 2 2 2 1 4]

# %%
fig = plt.figure()
fig.suptitle('Algorithm Accuracy Rates')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
models.append(('GBM', GradientBoostingClassifier()))
models.append(('RF', RandomForestClassifier()))
nb = GaussianNB()
gb = GradientBoostingClassifier()
rf = RandomForestClassifier()
best_model = rf
best_model.fit(x_train, y_train)
y_pred = best_model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, sur))
# Out:
#               precision    recall  f1-score   support
#
#         Fail       0.00      0.00      0.00         2
#         Pass       0.93      1.00      0.96        27
#
#     accuracy                           0.93        29
#    macro avg       0.47      0.50      0.48        29
# weighted avg       0.87      0.93      0.90        29
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
confusion_matrix_visual = confusion_matrix(y_test, sur)
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix_visual)
disp.plot()
plt.show()
